# %% [markdown]
# # LLM Call

# %%
from langchain_anthropic import ChatAnthropic
from dotenv import load_dotenv
import os
load_dotenv()


if os.getenv("ANTHROPIC_API_KEY") is None:
    raise ValueError("ANTHROPIC_API_KEY environment variable not set")
else:
    print('ANTHROPIC_API_KEY environment variable is set')
# Out:
# ANTHROPIC_API_KEY environment variable is set

# %%
llm = ChatAnthropic(model = 'claude-haiku-4-5-20251001')

response = llm.invoke('Give me the code to create a pandas dataframe with 3 columns and 5 rows of random data. Please also generate a python file to store the code.')

# %%
response.content
# Out:
# '# Here\'s the code to create a pandas DataFrame with random data:\n\n```python\nimport pandas as pd\nimport numpy as np\n\n# Create a DataFrame with 3 columns and 5 rows of random data\ndf = pd.DataFrame(\n    np.random.rand(5, 3),\n    columns=[\'Column1\', \'Column2\', \'Column3\']\n)\n\nprint(df)\n```\n\n## To save this as a Python file, follow these steps:\n\n**Option 1: Using a text editor**\n1. Create a new file named `create_dataframe.py`\n2. Copy the code above into the file\n3. Save it\n\n**Option 2: Using Python to create the file**\n```python\ncode = """import pandas as pd\nimport numpy as np\n\n# Create a DataFrame with 3 columns and 5 rows of random data\ndf = pd.DataFrame(\n    np.random.rand(5, 3),\n    columns=[\'Column1\', \'Column2\', \'Column3\']\n)\n\nprint(df)\n"""\n\nwith open(\'create_dataframe.py\', \'w\') as f:\n    f.write(code)\n\nprint("File \'create_dataframe.py\' created successfully!")\n```\n\n**Option 3: Run the file**\n```bash\npython create_dataframe.py\n```\n\nThis will create a DataFrame with random decimal values between 0 and 1. If you prefer different types of random data, let me know! 📊'
